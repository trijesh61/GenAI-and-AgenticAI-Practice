# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(model="llama-3.1-8b-instant",max_tokens=15
             ,temperature=0.1)
llm.invoke("First man to land on moon was")
# Out:
# AIMessage(content='The first man to land on the moon was Neil Armstrong. He stepped out', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 42, 'total_tokens': 57, 'completion_time': 0.018804616, 'completion_tokens_details': None, 'prompt_time': 0.002789684, 'prompt_tokens_details': None, 'queue_time': 0.159156124, 'total_time': 0.0215943}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019db9dc-f60c-7e32-9257-8db1b0d003bc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 42, 'output_tokens': 15, 'total_tokens': 57})

# %%
from langchain_core.prompts import PromptTemplate

# Instantiation using from_template (recommended)
prompt = PromptTemplate.from_template("write a poem on {item}")

prompt.invoke({"item":"dog"})
# Out:
# StringPromptValue(text='write a poem on dog')

# %%
llm=ChatGroq(model="llama-3.1-8b-instant",max_tokens=15
             ,temperature=0.1)
chain= prompt | llm
chain.invoke({"item":"dog"})
# Out:
# AIMessage(content="A furry friend, so loyal and true,\nA dog's love, forever", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 40, 'total_tokens': 55, 'completion_time': 0.020123954, 'completion_tokens_details': None, 'prompt_time': 0.003587742, 'prompt_tokens_details': None, 'queue_time': 0.159667305, 'total_time': 0.023711696}, 'model_name': 'llama-3.1-8b-instant', 'system_fingerprint': 'fp_7ccc667439', 'service_tier': 'on_demand', 'finish_reason': 'length', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019db9dc-fbc4-7ac0-8871-dd4789ffb2a2-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 15, 'total_tokens': 55})

# %% [markdown]
# # Output Parser

# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.exceptions import OutputParserException
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
prompt = '''
From the below news article, extract revenue and eps in JSON format containing the
following keys: 'revenue_actual', 'revenue_expected', 'eps_actual', 'eps_expected'. 

Each value should have a unit such as million or billion.

Only return the valid JSON. No preamble.

Article
=======
{article}
'''

pt = PromptTemplate.from_template(prompt)
pt
# Out:
# PromptTemplate(input_variables=['article'], input_types={}, partial_variables={}, template="\nFrom the below news article, extract revenue and eps in JSON format containing the\nfollowing keys: 'revenue_actual', 'revenue_expected', 'eps_actual', 'eps_expected'. \n\nEach value should have a unit such as million or billion.\n\nOnly return the valid JSON. No preamble.\n\nArticle\n=======\n{article}\n")

# %%
llm = ChatGroq(model_name="llama-3.3-70b-versatile")
chain = pt | llm

# %%
article_text=''' 
Here’s how Apple did versus LSEG consensus estimates for the quarter ending Sept. 27: 

EPS: $1.85 vs. $1.77 estimated  
Revenue: $102.47 billion vs. $102.24 billion estimated   '''


response = chain.invoke({'article': article_text})
response.content
# Out:
# '{"revenue_actual": "102.47 billion", "revenue_expected": "102.24 billion", "eps_actual": "1.85", "eps_expected": "1.77"}'

# %%
parser = JsonOutputParser()
res = parser.parse(response.content)
res
# Out:
# {'revenue_actual': '102.47 billion',
#  'revenue_expected': '102.24 billion',
#  'eps_actual': '1.85',
#  'eps_expected': '1.77'}

# %%
res['revenue_actual']
# Out:
# '102.47 billion'
