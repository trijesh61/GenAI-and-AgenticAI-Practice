# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq
llm=ChatGroq(model="llama-3.1-8b-instant",max_tokens=15
             ,temperature=0.6)

# %%
from langchain_core.prompts import PromptTemplate
prompt= PromptTemplate.from_template("I want to open a Resturant for {cusine} food. Suggest a fency Name for this")
name_chain=llm | prompt

prompt_items= PromptTemplate.from_template("Suggest {cusine} ")
